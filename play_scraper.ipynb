# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import requests

# %%
# Get the website html

url = ' https://www.nba.com/game/cle-vs-nyk-0042200134/play-by-play?period=All'

req = Request(url)
html_page = urlopen(req)
soup = BeautifulSoup(html_page, 'html5lib')

# %%
# ISSUE- This SHOULD return something but it won't!
game_rows = soup.select("article[class^='GamePlayByPlay']")

# %%
len(game_rows)
# Out:
# 0

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-build="6639" data-version="3.3.0" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="/site-manifest.json" rel="manifest"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
#   <script src="/newrelic/newrelic-prod.js">
#   </script>
#   <script id="theme-loader" src="/theme-loader.js">
#   </script>
#   <script src="/adfuel/initiator.js">
#   </script>
#   <title>
#    Cleveland Cavaliers vs New York Knicks Apr 23, 2023 Play-by-Play | NBA.com
#   </title>
#   <meta content="Cleveland Cavaliers vs New York Knicks Apr 23, 2023 game play-by-play" name="description"/>
#   <link href="/favicon.ico" rel="icon"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
# ...
